# %%
# %matplotlib widget
from gsm_ve import GSM_VE
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
pi_gsm_ve = GSM_VE()

# Material parameters
E_val = 30e+3  # Young's modulus in MPa
eta_val = 30e+6  # Viscosity modulus in Pa / s
mparams = (E_val, eta_val)

# Time step and final time
d_t_val = 0.01  # Time step in seconds
final_time = 20  # Final time in seconds

# Define the grid of amplitudes and cycles
amplitudes = np.round(np.linspace(0.1, 2, 20), 1)   # 20 Amplitude from 0.1% to 2%
cycles = np.arange(1, 11)  # Cycles from 1 to 10

for cycle in cycles:
    for amp in amplitudes:
        case_name = f"{cycle}C_{amp}A"  # Unique name (e.g., 2C1A for 2 cycles, 1% amplitude)
        
        # Generate time vector
        time_t = np.arange(0, final_time, d_t_val)
        
        # Generate sinusoidal strain history
        eps_t = (amp / 100) * np.sin(np.pi * cycle* time_t / final_time )  # Adjusted frequency

        pi_gsm_ve.problem_name = case_name #save data with uniqe nam
        
        # Perform integration (assuming pi_gsm_ve.perform_integration exists)
        gsm_ve_data = pi_gsm_ve.perform_integration(eps_t, time_t, *mparams)
        
        print(f"Processed case: {case_name}")
        save_path = pi_gsm_ve.data_dir / f'{case_name}.png'
        # Create a figure and axes
        fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(8, 10))

        # Plot results using the GSM_VE method
        pi_gsm_ve.plot_results(ax1, ax2, ax3, gsm_ve_data, case_name, 'blue')

        # Adjust layout
        fig.tight_layout()

        # Save the figure
        fig.savefig(save_path, dpi=300, bbox_inches="tight")
        print(f"Figure saved at: {save_path}")
        plt.close(fig)
# Out:
# Processed case: 1C_0.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_0.1A\1C_0.1A.png
# Processed case: 1C_0.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_0.2A\1C_0.2A.png
# Processed case: 1C_0.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_0.3A\1C_0.3A.png
# Processed case: 1C_0.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_0.4A\1C_0.4A.png
# Processed case: 1C_0.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_0.5A\1C_0.5A.png
# Processed case: 1C_0.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_0.6A\1C_0.6A.png
# Processed case: 1C_0.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_0.7A\1C_0.7A.png
# Processed case: 1C_0.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_0.8A\1C_0.8A.png
# Processed case: 1C_0.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_0.9A\1C_0.9A.png
# Processed case: 1C_1.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_1.0A\1C_1.0A.png
# Processed case: 1C_1.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_1.1A\1C_1.1A.png
# Processed case: 1C_1.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_1.2A\1C_1.2A.png
# Processed case: 1C_1.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_1.3A\1C_1.3A.png
# Processed case: 1C_1.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_1.4A\1C_1.4A.png
# Processed case: 1C_1.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_1.5A\1C_1.5A.png
# Processed case: 1C_1.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_1.6A\1C_1.6A.png
# Processed case: 1C_1.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_1.7A\1C_1.7A.png
# Processed case: 1C_1.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_1.8A\1C_1.8A.png
# Processed case: 1C_1.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_1.9A\1C_1.9A.png
# Processed case: 1C_2.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\1C_2.0A\1C_2.0A.png
# Processed case: 2C_0.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_0.1A\2C_0.1A.png
# Processed case: 2C_0.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_0.2A\2C_0.2A.png
# Processed case: 2C_0.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_0.3A\2C_0.3A.png
# Processed case: 2C_0.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_0.4A\2C_0.4A.png
# Processed case: 2C_0.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_0.5A\2C_0.5A.png
# Processed case: 2C_0.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_0.6A\2C_0.6A.png
# Processed case: 2C_0.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_0.7A\2C_0.7A.png
# Processed case: 2C_0.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_0.8A\2C_0.8A.png
# Processed case: 2C_0.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_0.9A\2C_0.9A.png
# Processed case: 2C_1.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_1.0A\2C_1.0A.png
# Processed case: 2C_1.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_1.1A\2C_1.1A.png
# Processed case: 2C_1.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_1.2A\2C_1.2A.png
# Processed case: 2C_1.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_1.3A\2C_1.3A.png
# Processed case: 2C_1.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_1.4A\2C_1.4A.png
# Processed case: 2C_1.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_1.5A\2C_1.5A.png
# Processed case: 2C_1.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_1.6A\2C_1.6A.png
# Processed case: 2C_1.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_1.7A\2C_1.7A.png
# Processed case: 2C_1.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_1.8A\2C_1.8A.png
# Processed case: 2C_1.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_1.9A\2C_1.9A.png
# Processed case: 2C_2.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\2C_2.0A\2C_2.0A.png
# Processed case: 3C_0.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_0.1A\3C_0.1A.png
# Processed case: 3C_0.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_0.2A\3C_0.2A.png
# Processed case: 3C_0.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_0.3A\3C_0.3A.png
# Processed case: 3C_0.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_0.4A\3C_0.4A.png
# Processed case: 3C_0.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_0.5A\3C_0.5A.png
# Processed case: 3C_0.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_0.6A\3C_0.6A.png
# Processed case: 3C_0.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_0.7A\3C_0.7A.png
# Processed case: 3C_0.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_0.8A\3C_0.8A.png
# Processed case: 3C_0.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_0.9A\3C_0.9A.png
# Processed case: 3C_1.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_1.0A\3C_1.0A.png
# Processed case: 3C_1.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_1.1A\3C_1.1A.png
# Processed case: 3C_1.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_1.2A\3C_1.2A.png
# Processed case: 3C_1.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_1.3A\3C_1.3A.png
# Processed case: 3C_1.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_1.4A\3C_1.4A.png
# Processed case: 3C_1.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_1.5A\3C_1.5A.png
# Processed case: 3C_1.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_1.6A\3C_1.6A.png
# Processed case: 3C_1.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_1.7A\3C_1.7A.png
# Processed case: 3C_1.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_1.8A\3C_1.8A.png
# Processed case: 3C_1.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_1.9A\3C_1.9A.png
# Processed case: 3C_2.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\3C_2.0A\3C_2.0A.png
# Processed case: 4C_0.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_0.1A\4C_0.1A.png
# Processed case: 4C_0.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_0.2A\4C_0.2A.png
# Processed case: 4C_0.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_0.3A\4C_0.3A.png
# Processed case: 4C_0.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_0.4A\4C_0.4A.png
# Processed case: 4C_0.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_0.5A\4C_0.5A.png
# Processed case: 4C_0.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_0.6A\4C_0.6A.png
# Processed case: 4C_0.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_0.7A\4C_0.7A.png
# Processed case: 4C_0.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_0.8A\4C_0.8A.png
# Processed case: 4C_0.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_0.9A\4C_0.9A.png
# Processed case: 4C_1.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_1.0A\4C_1.0A.png
# Processed case: 4C_1.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_1.1A\4C_1.1A.png
# Processed case: 4C_1.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_1.2A\4C_1.2A.png
# Processed case: 4C_1.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_1.3A\4C_1.3A.png
# Processed case: 4C_1.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_1.4A\4C_1.4A.png
# Processed case: 4C_1.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_1.5A\4C_1.5A.png
# Processed case: 4C_1.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_1.6A\4C_1.6A.png
# Processed case: 4C_1.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_1.7A\4C_1.7A.png
# Processed case: 4C_1.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_1.8A\4C_1.8A.png
# Processed case: 4C_1.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_1.9A\4C_1.9A.png
# Processed case: 4C_2.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\4C_2.0A\4C_2.0A.png
# Processed case: 5C_0.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_0.1A\5C_0.1A.png
# Processed case: 5C_0.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_0.2A\5C_0.2A.png
# Processed case: 5C_0.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_0.3A\5C_0.3A.png
# Processed case: 5C_0.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_0.4A\5C_0.4A.png
# Processed case: 5C_0.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_0.5A\5C_0.5A.png
# Processed case: 5C_0.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_0.6A\5C_0.6A.png
# Processed case: 5C_0.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_0.7A\5C_0.7A.png
# Processed case: 5C_0.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_0.8A\5C_0.8A.png
# Processed case: 5C_0.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_0.9A\5C_0.9A.png
# Processed case: 5C_1.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_1.0A\5C_1.0A.png
# Processed case: 5C_1.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_1.1A\5C_1.1A.png
# Processed case: 5C_1.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_1.2A\5C_1.2A.png
# Processed case: 5C_1.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_1.3A\5C_1.3A.png
# Processed case: 5C_1.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_1.4A\5C_1.4A.png
# Processed case: 5C_1.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_1.5A\5C_1.5A.png
# Processed case: 5C_1.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_1.6A\5C_1.6A.png
# Processed case: 5C_1.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_1.7A\5C_1.7A.png
# Processed case: 5C_1.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_1.8A\5C_1.8A.png
# Processed case: 5C_1.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_1.9A\5C_1.9A.png
# Processed case: 5C_2.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\5C_2.0A\5C_2.0A.png
# Processed case: 6C_0.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_0.1A\6C_0.1A.png
# Processed case: 6C_0.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_0.2A\6C_0.2A.png
# Processed case: 6C_0.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_0.3A\6C_0.3A.png
# Processed case: 6C_0.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_0.4A\6C_0.4A.png
# Processed case: 6C_0.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_0.5A\6C_0.5A.png
# Processed case: 6C_0.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_0.6A\6C_0.6A.png
# Processed case: 6C_0.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_0.7A\6C_0.7A.png
# Processed case: 6C_0.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_0.8A\6C_0.8A.png
# Processed case: 6C_0.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_0.9A\6C_0.9A.png
# Processed case: 6C_1.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_1.0A\6C_1.0A.png
# Processed case: 6C_1.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_1.1A\6C_1.1A.png
# Processed case: 6C_1.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_1.2A\6C_1.2A.png
# Processed case: 6C_1.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_1.3A\6C_1.3A.png
# Processed case: 6C_1.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_1.4A\6C_1.4A.png
# Processed case: 6C_1.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_1.5A\6C_1.5A.png
# Processed case: 6C_1.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_1.6A\6C_1.6A.png
# Processed case: 6C_1.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_1.7A\6C_1.7A.png
# Processed case: 6C_1.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_1.8A\6C_1.8A.png
# Processed case: 6C_1.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_1.9A\6C_1.9A.png
# Processed case: 6C_2.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\6C_2.0A\6C_2.0A.png
# Processed case: 7C_0.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_0.1A\7C_0.1A.png
# Processed case: 7C_0.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_0.2A\7C_0.2A.png
# Processed case: 7C_0.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_0.3A\7C_0.3A.png
# Processed case: 7C_0.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_0.4A\7C_0.4A.png
# Processed case: 7C_0.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_0.5A\7C_0.5A.png
# Processed case: 7C_0.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_0.6A\7C_0.6A.png
# Processed case: 7C_0.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_0.7A\7C_0.7A.png
# Processed case: 7C_0.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_0.8A\7C_0.8A.png
# Processed case: 7C_0.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_0.9A\7C_0.9A.png
# Processed case: 7C_1.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_1.0A\7C_1.0A.png
# Processed case: 7C_1.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_1.1A\7C_1.1A.png
# Processed case: 7C_1.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_1.2A\7C_1.2A.png
# Processed case: 7C_1.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_1.3A\7C_1.3A.png
# Processed case: 7C_1.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_1.4A\7C_1.4A.png
# Processed case: 7C_1.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_1.5A\7C_1.5A.png
# Processed case: 7C_1.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_1.6A\7C_1.6A.png
# Processed case: 7C_1.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_1.7A\7C_1.7A.png
# Processed case: 7C_1.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_1.8A\7C_1.8A.png
# Processed case: 7C_1.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_1.9A\7C_1.9A.png
# Processed case: 7C_2.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\7C_2.0A\7C_2.0A.png
# Processed case: 8C_0.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_0.1A\8C_0.1A.png
# Processed case: 8C_0.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_0.2A\8C_0.2A.png
# Processed case: 8C_0.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_0.3A\8C_0.3A.png
# Processed case: 8C_0.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_0.4A\8C_0.4A.png
# Processed case: 8C_0.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_0.5A\8C_0.5A.png
# Processed case: 8C_0.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_0.6A\8C_0.6A.png
# Processed case: 8C_0.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_0.7A\8C_0.7A.png
# Processed case: 8C_0.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_0.8A\8C_0.8A.png
# Processed case: 8C_0.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_0.9A\8C_0.9A.png
# Processed case: 8C_1.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_1.0A\8C_1.0A.png
# Processed case: 8C_1.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_1.1A\8C_1.1A.png
# Processed case: 8C_1.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_1.2A\8C_1.2A.png
# Processed case: 8C_1.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_1.3A\8C_1.3A.png
# Processed case: 8C_1.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_1.4A\8C_1.4A.png
# Processed case: 8C_1.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_1.5A\8C_1.5A.png
# Processed case: 8C_1.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_1.6A\8C_1.6A.png
# Processed case: 8C_1.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_1.7A\8C_1.7A.png
# Processed case: 8C_1.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_1.8A\8C_1.8A.png
# Processed case: 8C_1.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_1.9A\8C_1.9A.png
# Processed case: 8C_2.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\8C_2.0A\8C_2.0A.png
# Processed case: 9C_0.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_0.1A\9C_0.1A.png
# Processed case: 9C_0.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_0.2A\9C_0.2A.png
# Processed case: 9C_0.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_0.3A\9C_0.3A.png
# Processed case: 9C_0.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_0.4A\9C_0.4A.png
# Processed case: 9C_0.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_0.5A\9C_0.5A.png
# Processed case: 9C_0.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_0.6A\9C_0.6A.png
# Processed case: 9C_0.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_0.7A\9C_0.7A.png
# Processed case: 9C_0.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_0.8A\9C_0.8A.png
# Processed case: 9C_0.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_0.9A\9C_0.9A.png
# Processed case: 9C_1.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_1.0A\9C_1.0A.png
# Processed case: 9C_1.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_1.1A\9C_1.1A.png
# Processed case: 9C_1.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_1.2A\9C_1.2A.png
# Processed case: 9C_1.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_1.3A\9C_1.3A.png
# Processed case: 9C_1.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_1.4A\9C_1.4A.png
# Processed case: 9C_1.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_1.5A\9C_1.5A.png
# Processed case: 9C_1.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_1.6A\9C_1.6A.png
# Processed case: 9C_1.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_1.7A\9C_1.7A.png
# Processed case: 9C_1.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_1.8A\9C_1.8A.png
# Processed case: 9C_1.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_1.9A\9C_1.9A.png
# Processed case: 9C_2.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\9C_2.0A\9C_2.0A.png
# Processed case: 10C_0.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_0.1A\10C_0.1A.png
# Processed case: 10C_0.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_0.2A\10C_0.2A.png
# Processed case: 10C_0.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_0.3A\10C_0.3A.png
# Processed case: 10C_0.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_0.4A\10C_0.4A.png
# Processed case: 10C_0.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_0.5A\10C_0.5A.png
# Processed case: 10C_0.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_0.6A\10C_0.6A.png
# Processed case: 10C_0.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_0.7A\10C_0.7A.png
# Processed case: 10C_0.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_0.8A\10C_0.8A.png
# Processed case: 10C_0.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_0.9A\10C_0.9A.png
# Processed case: 10C_1.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_1.0A\10C_1.0A.png
# Processed case: 10C_1.1A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_1.1A\10C_1.1A.png
# Processed case: 10C_1.2A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_1.2A\10C_1.2A.png
# Processed case: 10C_1.3A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_1.3A\10C_1.3A.png
# Processed case: 10C_1.4A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_1.4A\10C_1.4A.png
# Processed case: 10C_1.5A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_1.5A\10C_1.5A.png
# Processed case: 10C_1.6A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_1.6A\10C_1.6A.png
# Processed case: 10C_1.7A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_1.7A\10C_1.7A.png
# Processed case: 10C_1.8A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_1.8A\10C_1.8A.png
# Processed case: 10C_1.9A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_1.9A\10C_1.9A.png
# Processed case: 10C_2.0A
# Figure saved at: C:\Users\adelpasand\bmcs_training_data\10C_2.0A\10C_2.0A.png

# %%
import numpy as np
import glob
from pathlib import Path

# Define the data directory (update this if necessary)
data_dir = pi_gsm_ve.data_dir  # Change this to your actual directory

# Get all NumPy files in the data directory
npy_files = sorted(glob.glob(str(data_dir / "*.npy")))

# Initialize lists to store data
strain_data = []
stress_data = []
internal_var_data = []

# Load each .npy file
for file in npy_files:
    try:
        data = np.load(file, allow_pickle=True).item()  # Assuming data is stored as a dictionary

        # Ensure necessary keys exist
        if all(key in data for key in ["strain", "stress", "internal_variable"]):
            strain_data.append(data["strain"])
            stress_data.append(data["stress"])
            internal_var_data.append(data["internal_variable"])
        else:
            print(f"Skipping {file}, missing required keys.")
    
    except Exception as e:
        print(f"Error loading {file}: {e}")

# Convert lists to NumPy arrays
strain_data = np.array(strain_data)
stress_data = np.array(stress_data)
internal_var_data = np.array(internal_var_data)

# Print shapes of loaded data
print(f"Loaded strain data shape: {strain_data.shape}")
print(f"Loaded stress data shape: {stress_data.shape}")
print(f"Loaded internal variable data shape: {internal_var_data.shape}")

# Now the data is ready to be used for training the neural network
